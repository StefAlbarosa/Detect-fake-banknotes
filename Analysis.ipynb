# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Libraries-and-Data-Exploration" data-toc-modified-id="Libraries-and-Data-Exploration-0.0.1"><span class="toc-item-num">0.0.1&nbsp;&nbsp;</span>Libraries and Data Exploration</a></span></li></ul></li><li><span><a href="#Dataframes-preparation" data-toc-modified-id="Dataframes-preparation-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Dataframes preparation</a></span><ul class="toc-item"><li><span><a href="#Normal-distribution-test" data-toc-modified-id="Normal-distribution-test-0.1.1"><span class="toc-item-num">0.1.1&nbsp;&nbsp;</span>Normal distribution test</a></span></li><li><span><a href="#Standard-Scaler" data-toc-modified-id="Standard-Scaler-0.1.2"><span class="toc-item-num">0.1.2&nbsp;&nbsp;</span>Standard Scaler</a></span></li><li><span><a href="#PCA" data-toc-modified-id="PCA-0.1.3"><span class="toc-item-num">0.1.3&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#Correlation-circle" data-toc-modified-id="Correlation-circle-0.1.4"><span class="toc-item-num">0.1.4&nbsp;&nbsp;</span>Correlation circle</a></span></li><li><span><a href="#Projection-of-points" data-toc-modified-id="Projection-of-points-0.1.5"><span class="toc-item-num">0.1.5&nbsp;&nbsp;</span>Projection of points</a></span></li><li><span><a href="#PCA-reduced-df" data-toc-modified-id="PCA-reduced-df-0.1.6"><span class="toc-item-num">0.1.6&nbsp;&nbsp;</span>PCA reduced df</a></span></li></ul></li></ul></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Logistic Regression</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Dataframes-Preparation" data-toc-modified-id="Dataframes-Preparation-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Dataframes Preparation</a></span></li><li><span><a href="#OLS-models" data-toc-modified-id="OLS-models-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>OLS models</a></span></li><li><span><a href="#Probability-graphs" data-toc-modified-id="Probability-graphs-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Probability graphs</a></span></li><li><span><a href="#Test-Split" data-toc-modified-id="Test-Split-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>Test Split</a></span></li><li><span><a href="#Model-summary-tables" data-toc-modified-id="Model-summary-tables-1.0.5"><span class="toc-item-num">1.0.5&nbsp;&nbsp;</span>Model summary tables</a></span></li><li><span><a href="#Choosing-the-model" data-toc-modified-id="Choosing-the-model-1.0.6"><span class="toc-item-num">1.0.6&nbsp;&nbsp;</span>Choosing the model</a></span></li></ul></li></ul></li><li><span><a href="#K-means" data-toc-modified-id="K-means-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>K-means</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#K-means" data-toc-modified-id="K-means-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>K-means</a></span></li></ul></li></ul></li><li><span><a href="#Final-model" data-toc-modified-id="Final-model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Final model</a></span><ul class="toc-item"><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Data Exploration</a></span></li><li><span><a href="#Train-and-predict" data-toc-modified-id="Train-and-predict-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Train and predict</a></span><ul class="toc-item"><li><span><a href="#Train" data-toc-modified-id="Train-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Train</a></span></li><li><span><a href="#Test" data-toc-modified-id="Test-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Test</a></span></li><li><span><a href="#Result" data-toc-modified-id="Result-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Result</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ### Libraries and Data Exploration

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from functions import *


#For Normal Distribution test Q-Q plot
from scipy import stats

#For standard Scaler
from sklearn.preprocessing import StandardScaler

#For PCA
from sklearn.decomposition import PCA

#Split Train
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score


import statsmodels.formula.api as smf

# For some graphs I got warnings that I corrected but kept popping up anyways so I needed these:
import os
import warnings


from sklearn.cluster import KMeans

from fuzzywuzzy import process

from sklearn.metrics import confusion_matrix


import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# C:\Users\Stefania\.anaconda\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df_original=pd.read_csv('raw_data/notes.csv')
df_test = pd.read_csv('raw_data/test.csv')

# %%
#Just wanted to keep a copy of the original in case needed. 
df = df_original.copy()

# %%
#Summary statistics
display(df.info())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    170 non-null    bool
#  1   diagonal      170 non-null    float64
#  2   height_left   170 non-null    float64
#  3   height_right  170 non-null    float64
#  4   margin_low    170 non-null    float64
#  5   margin_up     170 non-null    float64
#  6   length        170 non-null    float64
# dtypes: bool(1), float64(6)
# memory usage: 8.3 KB
# None
#          diagonal  height_left  height_right  margin_low   margin_up  \
# count  170.000000   170.000000    170.000000  170.000000  170.000000
# mean   171.940588   104.066353    103.928118    4.612118    3.170412
# std      0.305768     0.298185      0.330980    0.702103    0.236361
# min    171.040000   103.230000    103.140000    3.540000    2.270000
# 25%    171.730000   103.842500    103.690000    4.050000    3.012500
# ...

# %%
# boolean values plot
df['is_genuine'].value_counts().plot(kind='bar')
plt.xlabel('is_genuine')
plt.ylabel('Count')
plt.title('Count of Genuine vs. Non-Genuine')
plt.show()

# %%
# Distribution visualization
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))

#I don't want the boolean column for these plots.
df_num=df[['diagonal', 'height_left', 'height_right', 'margin_low',
       'margin_up', 'length']]

for i, column in enumerate(df_num.columns):
    sns.histplot(df_num[column], ax=axes[i//3, i%3], kde=True)
    axes[i//3, i%3].set_title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# %%
# Correlation matrix
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(df,hue = 'is_genuine' )
plt.title('Pairplot')
plt.show()
# Out:
# C:\Users\Stefania\.anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# There is a clear differentiation between true and false values.

# %% [markdown]
# ## Dataframes preparation

# %%
#making a new df of only the is_genuine column
df_g = pd.DataFrame()  
df_g['is_genuine'] = df['is_genuine'].copy()

# %%
df = df.drop('is_genuine', axis = 1)

# %% [markdown]
# ### Normal distribution test

# %%
# Checking if my data is Guassian, normally distributed or not.
for column in df.columns:
    # Plot histograms
    sns.histplot(df[column], kde=True)
    plt.title(f'Histogram of {column}')
    plt.show()
    # Interpretation: should be showing a normal distribution graph if its Guassian.
    
    # Q-Q plot
    stats.probplot(df[column], dist="norm", plot=plt)
    plt.title(f'Q-Q plot of {column}')
    plt.show()
    # Interpretation: should be shoing data points on the line if its Guassian
    
    # Shapiro-Wilk Test
    shapiro_test = stats.shapiro(df[column])
    print(f'Shapiro-Wilk Test for {column}: p-value={shapiro_test[1]}')
    # Should be over 0.05 if it is Guassian
    
    # D’Agostino’s K^2 Test
    dagostino_test = stats.normaltest(df[column])
    print(f'D’Agostino’s K^2 Test for {column}: p-value={dagostino_test[1]}\n')
    # Should be over 0.05 if its Guassian
# Out:
# Shapiro-Wilk Test for diagonal: p-value=0.6108110547065735
# D’Agostino’s K^2 Test for diagonal: p-value=0.19018994287454516
# Shapiro-Wilk Test for height_left: p-value=0.5533661246299744
# D’Agostino’s K^2 Test for height_left: p-value=0.3290862900476634
# Shapiro-Wilk Test for height_right: p-value=0.16248995065689087
# D’Agostino’s K^2 Test for height_right: p-value=0.6475193149394053
# Shapiro-Wilk Test for margin_low: p-value=6.22558673057938e-07
# D’Agostino’s K^2 Test for margin_low: p-value=0.00010190623504607456
# Shapiro-Wilk Test for margin_up: p-value=0.20442229509353638
# D’Agostino’s K^2 Test for margin_up: p-value=0.2003556047699367
# Shapiro-Wilk Test for length: p-value=3.7148348042137513e-07
# D’Agostino’s K^2 Test for length: p-value=0.0007376925090803203

# %% [markdown]
# The only non-normally distributed is; is_genuine (its boolean) and lenght.

# %% [markdown]
# ### Standard Scaler

# %%
scaler = StandardScaler()
scaler.fit(df)
scaled=scaler.transform(df)

# %%
df_sc = pd.DataFrame(scaled, columns=df.columns)

# %%
df_sc.plot(kind='density',sharex=True,figsize=(12,5),layout=(10,1))
# Out:
# <Axes: ylabel='Density'>

# %%
df_sc.head(2)
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up    length
# 0 -0.428344     2.669454      3.096563   -0.131590  -1.189874  0.281633
# 1 -0.887559    -1.097697     -0.691254   -0.860126  -1.274740  0.780697

# %% [markdown]
# ### PCA

# %%
pca = PCA()
pca.fit(df_sc)
# Out:
# PCA()

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.47447921, 0.69405027, 0.83639551, 0.92165846, 0.96778669,
#        1.        ])

# %%
display_scree_plot(pca)

# %% [markdown]
#  I picked 5, as the number of pca components I want to keep

# %%
pc1 = pca.components_[0]
pc2 = pca.components_[1]
pc3 = pca.components_[2]
pc4 = pca.components_[3]
pc5 = pca.components_[4]

# %% [markdown]
# ### Correlation circle

# %%
num_components = 5
pcs = pca.components_
display_circles(pcs, num_components, pca, [(0,1)], labels = np.array(df.columns))

# %% [markdown]
# ### Projection of points

# %%
# make new variable only using 'is_genuine', for using it in the next plot 
rank_band = [df_g.loc[index, "is_genuine"] for index in range(0,len(df_sc))]

# %%
# Transform the original scaled data to the new vector space and display data points
df_projected = pca.transform(df_sc)
display_factorial_planes(df_projected, num_components, pca, [(0,1)], illustrative_var = rank_band, alpha = 0.5)

# %% [markdown]
# Seems like our PCA0 -PCA1 retained information very well.

# %%
# Lets check how pc1 and pc2 plot looks like
display_factorial_planes(df_projected, num_components, pca, [(1,2)], illustrative_var = rank_band, alpha = 0.5)

# %% [markdown]
# PCA2 didn't retain much information.

# %% [markdown]
# ###  PCA reduced df

# %%
# Create a PCA model to reduce our data for visualisation
pca = PCA(n_components=5)
pca.fit(df_sc)

# Transfor the scaled data to the new PCA space
df_pca = pca.transform(df_sc)

# %%
df_pca=pd.DataFrame(df_pca, index=df.index, columns=['PC1','PC2','PC3','PC4', 'PC5'])
df_pca.head(2)
# Out:
#         PC1       PC2       PC3       PC4      PC5
# 0  2.153639  1.599709  1.787451  2.433465  0.69969
# 1 -2.110416 -0.526039  0.542563  0.344550  0.06744

# %% [markdown]
#   # Logistic Regression

# %% [markdown]
# ### Dataframes Preparation

# %%
#let's make 2 new dataframes with the log of df and df_sc just to see what performs best with our model. 
df_log = np.log(df)

# %%
data_frames = {'df': df, 'df_sc': df_sc, 'df_log': df_log,'df_pca': df_pca}

# %%
data_frames
# Out:
# {'df':      diagonal  height_left  height_right  margin_low  margin_up  length
#  0      171.81       104.86        104.95        4.52       2.89  112.83
#  1      171.67       103.74        103.70        4.01       2.87  113.29
#  2      171.83       103.76        103.76        4.40       2.88  113.84
#  3      171.80       103.78        103.65        3.73       3.12  113.63
#  4      172.05       103.70        103.75        5.04       2.27  113.55
#  ..        ...          ...           ...         ...        ...     ...
#  165    172.11       104.23        104.45        5.24       3.58  111.78
#  166    173.01       104.59        104.31        5.04       3.05  110.91
#  167    172.47       104.27        104.10        4.88       3.33  110.68
#  168    171.82       103.97        103.88        4.73       3.55  111.87
#  169    171.96       104.00        103.95        5.63       3.26  110.96
#
#  [170 rows x 6 columns],
# ...

# %%
for name, data_frame in data_frames.items():
    data_frame['is_genuine'] = df_original ['is_genuine']
    data_frames[name] = data_frame  # Update the dictionary with the modified DataFrame
    display(name, data_frame.head(2)) 
    display(name, data_frame.info())
    
#Append it in a list
# Out:
# 'df'
#    diagonal  height_left  height_right  margin_low  margin_up  length  \
# 0    171.81       104.86        104.95        4.52       2.89  112.83
# 1    171.67       103.74        103.70        4.01       2.87  113.29
#
#    is_genuine
# 0        True
# 1        True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   diagonal      170 non-null    float64
#  1   height_left   170 non-null    float64
#  2   height_right  170 non-null    float64
#  3   margin_low    170 non-null    float64
#  4   margin_up     170 non-null    float64
#  5   length        170 non-null    float64
#  6   is_genuine    170 non-null    bool
# dtypes: bool(1), float64(6)
# memory usage: 8.3 KB
# 'df'
# None
# 'df_sc'
#    diagonal  height_left  height_right  margin_low  margin_up    length  \
# ...

# %% [markdown]
# ### OLS models

# %% [markdown]
# I ran a OLS model below simply to take a look at the correlations between the is_genuine and other factors.

# %%
#Lets change the column of True/False values to 1/0 values.
for name, data_frame in data_frames.items():
    data_frame['is_genuine'] = (data_frame['is_genuine'] == True).astype(int)

# %%
# I don't need the pca dataframe for this so I am making a smaller list of just df and df_sc
data_frames_ols_values = list(data_frames.values())
data_frames_ols = data_frames_ols_values[:3]

# %%
for data_frame in data_frames_ols:
    data_frame['is_genuine'] = (data_frame['is_genuine'] == True).astype(int)
    model = smf.ols(formula='is_genuine ~ diagonal + height_left + height_right + margin_low + margin_up + length', data=data_frame)   
    results1 = model.fit()
    print(results1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             is_genuine   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     208.0
# Date:                Thu, 09 May 2024   Prob (F-statistic):           1.11e-73
# Time:                        16:59:56   Log-Likelihood:                 62.745
# No. Observations:                 170   AIC:                            -111.5
# Df Residuals:                     163   BIC:                            -89.54
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      -14.0754      8.459     -1.664      0.098     -30.778       2.627
# ...

# %% [markdown]
# Notes on df dataframe:
# R-squared: It is over 0.88 for both dataframes, which means that over 88% of the variance of is_genuine can be explaied by the other variables.
#
# F-statistic probability (1.11e-73),: It is very low, (<0.05) meaning that the overal model is significant
#
# Coefficients: The coefficients for "diagonal," "height_left," "height_right," "margin_low," "margin_up," and "length" represent the estimated change in "is_genuine" for a one-unit increase in each respective independent variable.
#
# P>|t| (p-values): These indicate the significance of each coefficient. Some of our the coefficients of variables are not significant.
#
# Therefore, we take them out.

# %% [markdown]
# I am going to run the ols again without these columns

# %%
probs_list = []
r_squared = []

# %%
for data_frame in data_frames_ols:
    data_frame['is_genuine'] = (data_frame['is_genuine'] == True).astype(int)
    model = smf.ols(formula='is_genuine ~ margin_low + margin_up + length', data=data_frame)   
    results1 = model.fit()
    print(results1.summary())
    proba = 1 / (1 + np.exp( - results1.fittedvalues ))
    probs_list.append(proba)    
    r_squared.append(results1.rsquared)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             is_genuine   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     415.1
# Date:                Thu, 09 May 2024   Prob (F-statistic):           6.89e-77
# Time:                        16:59:56   Log-Likelihood:                 61.227
# No. Observations:                 170   AIC:                            -114.5
# Df Residuals:                     166   BIC:                            -101.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -13.4644      2.682     -5.020      0.000     -18.760      -8.169
# ...

# %% [markdown]
# Now the p values are all 0.

# %% [markdown]
# I am goingt to do the same with the PCA data

# %%
#Transfrorming the 
data_frames['df_pca']['is_genuine'] = (data_frames['df_pca']['is_genuine'] == True).astype(int)
model = smf.ols(formula='is_genuine ~ PC1 + PC2 + PC3 + PC4 + PC5', data=data_frames['df_pca'])   
results2 = model.fit()
print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             is_genuine   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     234.6
# Date:                Thu, 09 May 2024   Prob (F-statistic):           8.97e-73
# Time:                        16:59:56   Log-Likelihood:                 57.649
# No. Observations:                 170   AIC:                            -103.3
# Df Residuals:                     164   BIC:                            -84.48
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5882      0.013     43.700      0.000       0.562       0.615
# ...

# %% [markdown]
# Notes on df_pca dataframe:
# R-squared: It is over 0.87, which means that over 87% of the variance of is_genuine can be explaied by the PCAs.
#
# F-statistic probability (234.6),: It not enough low, (>0.05) meaning that the overal model is not significant.
#
# Coefficients: The coefficients for PCAs represent the estimated change in "is_genuine" for a one-unit increase in each respective independent variable.
#
# P>|t| (p-values): These indicate the significance of each coefficient. PC3 coefficients of variables is not significant.the rest seems significant, at 0.
#
# Therefore I elminate P3

# %%
#Transfrorming the 
data_frames['df_pca']['is_genuine'] = (data_frames['df_pca']['is_genuine'] == True).astype(int)
model = smf.ols(formula='is_genuine ~ PC1 + PC2 + PC4 + PC5', data=data_frames['df_pca'])   
results2 = model.fit()
probs_list.append(proba)    
r_squared.append(results2.rsquared)
print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             is_genuine   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     293.8
# Date:                Thu, 09 May 2024   Prob (F-statistic):           6.54e-74
# Time:                        16:59:56   Log-Likelihood:                 57.350
# No. Observations:                 170   AIC:                            -104.7
# Df Residuals:                     165   BIC:                            -89.02
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5882      0.013     43.756      0.000       0.562       0.615
# ...

# %%
r_squared
# Out:
# [0.8823760637635945,
#  0.8823760637635943,
#  0.8811532453093863,
#  0.8768872473836564]

# %%
# Since the ols models show that they work better without the eliminated columns, I am going to drop them.
# Columns to eliminate
columns_to_drop = ['diagonal', 'height_left', 'height_right']

# Dropping columns from the first four dataframes
for key in data_frames.keys():
    if key != 'df_pca':  # Exclude 'df_pca' since it has different columns
        data_frames[key] = data_frames[key].drop(columns=columns_to_drop)

#Also drop pc3 from the pca dataframe.
data_frames['df_pca'] = data_frames['df_pca'].drop(columns='PC3')

# Printing the modified dataframes
for key, value in data_frames.items():
    print(f"{key}:")
    print(value)
    print()
# Out:
# df:
#      margin_low  margin_up  length  is_genuine
# 0          4.52       2.89  112.83           1
# 1          4.01       2.87  113.29           1
# 2          4.40       2.88  113.84           1
# 3          3.73       3.12  113.63           1
# 4          5.04       2.27  113.55           1
# ..          ...        ...     ...         ...
# 165        5.24       3.58  111.78           0
# 166        5.04       3.05  110.91           0
# 167        4.88       3.33  110.68           0
# 168        4.73       3.55  111.87           0
# 169        5.63       3.26  110.96           0
#
# [170 rows x 4 columns]
#
# df_sc:
#      margin_low  margin_up    length  is_genuine
# 0     -0.131590  -1.189874  0.281633           1
# 1     -0.860126  -1.274740  0.780697           1
# 2     -0.303010  -1.232307  1.377405           1
# 3     -1.260106  -0.213913  1.149571           1
# 4      0.611230  -3.820725  1.062777           1
# ..          ...        ...       ...         ...
# ...

# %% [markdown]
# ### Probability graphs

# %% [markdown]
# I graphed some of the probabilities of the points being within the True (1) or False(0), they all look very similar

# %%
probs_list[0].hist(bins=50, color= 'lightsalmon')
# Out:
# <Axes: >

# %%
probs_list[1].hist(bins=50, color= 'lightsalmon')
# Out:
# <Axes: >

# %%
probs_list[2].hist(bins=50, color= 'lightsalmon')
# Out:
# <Axes: >

# %% [markdown]
# ### Test Split

# %%
from sklearn.metrics import confusion_matrix

def logistic_regression_train_test(data, target_column, test_size=0.8, random_state=42):
    """
    Perform logistic regression on the provided DataFrame and evaluate using confusion matrix.
    
    Args:
    - data: DataFrame containing the data
    - target_column: Name of the column containing the target variable
    - test_size: Proportion of the dataset to include in the test split (default is 0.8)
    - random_state: Random seed for reproducibility (default is 42)
    
    Returns:
    - accuracy: Accuracy of the logistic regression model on the test set
    - conf_matrix: Confusion matrix of the model predictions on the test set
    """
    # Convert boolean target variable to integers (0 and 1)
    data[target_column] = data[target_column].astype(int)
    
    # Splitting the data into features (X) and the target variable (y)
    X = data.drop(target_column, axis=1)
    y = data[target_column]
    
    # Splitting the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    
    # Training the logistic regression model
    model = LogisticRegression()
    model.fit(X_train, y_train)
    
    # Making predictions on the test set
    y_pred = model.predict(X_test)
    
    # Calculating accuracy
    accuracy = accuracy_score(y_test, y_pred)
    
    # Calculating confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    return accuracy, conf_matrix

# %%
y_pred_list = []
accuracies = []

for name, data_frame in data_frames.items():
    data_frame_accuracy, conf_matrix = logistic_regression_train_test(data_frame, 'is_genuine')
    accuracies.append(data_frame_accuracy)  # Append the accuracy to the accuracies list
    y_pred_list.append(conf_matrix)  # Append confusion matrix to y_pred_list
    #create a list y_pred_list and put y_pred into it.
    print("Accuracy for", name, ":", data_frame_accuracy) 
    print()
    # Extract values from the confusion matrix
    TN, FP, FN, TP = conf_matrix.ravel()
    # Display the prediction table
    print("Confusion Matrix for", name, ":")
    print("True Negatives (TN):", TN)
    print("False Positives (FP):", FP)
    print("False Negatives (FN):", FN)
    print("True Positives (TP):", TP)
    print()
# Out:
# Accuracy for df : 0.9852941176470589
#
# Confusion Matrix for df :
# True Negatives (TN): 53
# False Positives (FP): 1
# False Negatives (FN): 1
# True Positives (TP): 81
#
# Accuracy for df_sc : 0.9926470588235294
#
# Confusion Matrix for df_sc :
# True Negatives (TN): 54
# False Positives (FP): 0
# False Negatives (FN): 1
# True Positives (TP): 81
#
# Accuracy for df_log : 0.9558823529411765
#
# Confusion Matrix for df_log :
# True Negatives (TN): 48
# False Positives (FP): 6
# False Negatives (FN): 0
# True Positives (TP): 82
#
# Accuracy for df_pca : 0.9632352941176471
#
# Confusion Matrix for df_pca :
# True Negatives (TN): 54
# False Positives (FP): 0
# False Negatives (FN): 5
# True Positives (TP): 77

# %% [markdown]
# ### Model summary tables

# %%
# Extract columns from data frames
columns = [list(data_frames[name].columns) for name in data_frames]

# Create a dictionary to hold the data
data = {
    'Columns': columns,
    'R-squared': r_squared,
    'Accuracy': accuracies,
    'TN':TN,
    'FP':FP,
    'FN':FN,
    'TP':TP,
}

df_table = pd.DataFrame(data, index=data_frames)
display(df_table)
# Out:
#                                             Columns  R-squared  Accuracy  TN  \
# df      [margin_low, margin_up, length, is_genuine]   0.882376  0.985294  54
# df_sc   [margin_low, margin_up, length, is_genuine]   0.882376  0.992647  54
# df_log  [margin_low, margin_up, length, is_genuine]   0.881153  0.955882  54
# df_pca             [PC1, PC2, PC4, PC5, is_genuine]   0.876887  0.963235  54
#
#         FP  FN  TP
# df       0   5  77
# df_sc    0   5  77
# df_log   0   5  77
# df_pca   0   5  77

# %% [markdown]
# ### Choosing the model

# %% [markdown]
# I am picking one dataframe from all this going forward, the one with the highest accuracy, so df_sc. Because I am only going to work with this dataframe from now on, I am going to make a new copy of it simply to not have to refer to it within the data_frame list.

# %%
df_sc_final = data_frames['df_sc'].copy()

# %% [markdown]
# # K-means

# %% [markdown]
# I will also check if K-means has come up with similar results, for re-assurance.

# %% [markdown]
# ### K-means

# %%
def kmeans_clustering(data, n_clusters=2, init='random', n_init=10):
    """
    Perform k-means clustering on the specified data frame.
    
    Parameters:
    data (DataFrame): The data frame to be clustered.
    n_clusters (int): The number of clusters to form.
    init (str): The method for initialization.
    n_init (int): Number of times the k-means algorithm will be run with different centroid seeds.
    
    Returns:
    clusters (array): An array containing the cluster labels for each data point.
    """
    # Create a k-means clustering model
    kmeans = KMeans(init=init, n_clusters=n_clusters, n_init=n_init)
    
    # Fit the data to the model
    kmeans.fit(data)
    
    # Determine which clusters each data point belongs to:
    clusters = kmeans.predict(data)
    
    return clusters

# %%
#This is just because there were some warnings poppin up even if I corrected them.
os.environ["OMP_NUM_THREADS"] = "1"
warnings.filterwarnings("ignore")

# %%
#Apply k means function:
clusters_k = kmeans_clustering(df_sc_final, n_clusters=2)
df_sc_final['clusters'] = clusters_k

# %%
#Lets check if its added, yes it is. 
df_sc_final.head()
# Out:
#    margin_low  margin_up    length  is_genuine  clusters
# 0   -0.131590  -1.189874  0.281633           1         0
# 1   -0.860126  -1.274740  0.780697           1         0
# 2   -0.303010  -1.232307  1.377405           1         0
# 3   -1.260106  -0.213913  1.149571           1         0
# 4    0.611230  -3.820725  1.062777           1         0

# %%
### I know that, k-means puts the values randomly into these two categories. 
# Which means sometimes, the category 0 will refre to when the is_genuine is 1. 
#I want to compare the accuracy but it is easier if I have the k-mean categories categorized to match with is_genuine.

# Comparing the second line's is_genuine and clusters values
if df_sc_final.at[1, 'clusters'] != df_sc_final.at[1, 'is_genuine']:
    # Inverting the clusters column values
    df_sc_final['clusters'] = df_sc_final['clusters'].apply(lambda x: 1 if x == 0 else 0)

print(df_sc_final.head())
# Out:
#    margin_low  margin_up    length  is_genuine  clusters
# 0   -0.131590  -1.189874  0.281633           1         1
# 1   -0.860126  -1.274740  0.780697           1         1
# 2   -0.303010  -1.232307  1.377405           1         1
# 3   -1.260106  -0.213913  1.149571           1         1
# 4    0.611230  -3.820725  1.062777           1         1

# %%
#lets plot 

margin_low = df_sc_final['margin_low']
margin_up = df_sc_final ['margin_up']
lenght = df_sc_final ['length']


# Scatter plot for training data
sns.scatterplot(x=margin_low, y=margin_up, hue=df_sc_final['clusters'], palette=['palevioletred', 'thistle'], alpha=0.8)


plt.xlabel('Margin low')
plt.ylabel('Margin up')
plt.title('Scatter Plot of Margins')

# Add legend with both training and test data labels
plt.legend(title='Genuine', loc='lower left')

plt.show()

# %%
# Create sets for 'is_genuine' column
is_genuine_0 = set(df_sc[df_sc_final['is_genuine'] == 0].index)
is_genuine_1 = set(df_sc[df_sc_final['is_genuine'] == 1].index)

# Create sets for 'clusters' column
clusters_0 = set(df_sc[df_sc_final['clusters'] == 0].index)
clusters_1 = set(df_sc[df_sc_final['clusters'] == 1].index)

# %%
# Group by 'is_genuine' and 'clusters' and count occurrences
counts = df_sc_final.groupby(['is_genuine', 'clusters']).size().reset_index(name='count')

# Print the result
print(counts)
# Out:
#    is_genuine  clusters  count
# 0           0         0     70
# 1           1         0      1
# 2           1         1     99

# %% [markdown]
# The K-means came up with the same values, one fake negative. I am going to go with train test from now on because as we have seen with the confusion matrix:
#
# Confusion Matrix for df_sc :
# True Negatives (TN): 70
# False Positives (FP): 0
# False Negatives (FN): 1
# True Positives (TP): 99
#
# Here as well there is only one mis-categorized value. Therefore I am goingt to drop the clousters column and continue with my train test

# %%
df_sc_final.drop(columns=['clusters'], inplace = True)

# %%
df_sc_final
# Out:
#      margin_low  margin_up    length  is_genuine
# 0     -0.131590  -1.189874  0.281633           1
# 1     -0.860126  -1.274740  0.780697           1
# 2     -0.303010  -1.232307  1.377405           1
# 3     -1.260106  -0.213913  1.149571           1
# 4      0.611230  -3.820725  1.062777           1
# ..          ...        ...       ...         ...
# 165    0.896930   1.738009 -0.857535           0
# 166    0.611230  -0.510944 -1.801418           0
# 167    0.382670   0.677182 -2.050950           0
# 168    0.168395   1.610710 -0.759892           0
# 169    1.454046   0.380151 -1.747172           0
#
# [170 rows x 4 columns]

# %% [markdown]
# # Final model

# %% [markdown]
# ## Data Exploration

# %%
# Lets look at the test data
df_test
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id
# 0    171.76       104.01        103.54        5.21       3.30  111.42  A_1
# 1    171.87       104.17        104.13        6.00       3.31  112.09  A_2
# 2    172.00       104.58        104.29        4.99       3.39  111.57  A_3
# 3    172.49       104.55        104.34        4.44       3.03  113.20  A_4
# 4    171.65       103.63        103.56        3.77       3.16  113.33  A_5

# %%
#lets plot 

margin_low_df = df['margin_low']
margin_up_df = df ['margin_up']
lenght_df = df ['length']


margin_low_test = df_test['margin_low']
margin_up_test = df_test ['margin_up']
lenght_test = df_test ['length']

# Scatter plot for training data
sns.scatterplot(x=margin_low_df, y=margin_up_df, hue=df['is_genuine'], palette=['palevioletred', 'thistle'], alpha=0.8)

# Scatter plot for test data
sns.scatterplot(x=margin_low_test, y=margin_up_test, color='darkslategray', alpha=0.7)

plt.xlabel('Margin low')
plt.ylabel('Margin up')
plt.title('Scatter Plot of Margins')


# Create custom legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()
custom_handles = handles[:2] + [plt.Line2D([0], [0], marker='o', color='darkslategray', markersize=5, linestyle='None')]  # Custom handle for test data
custom_labels = labels[:2] + ['test']

# Add legend with both training and test data labels
plt.legend(custom_handles, custom_labels, title='Genuine')
plt.show()

# %% [markdown]
# ## Train and predict

# %% [markdown]
# I am going to re-run the logistic regression model but this time without the train test split to use all information possible for the prediction when running it on the test data.

# %%
#Printing the test dataframe
df_test
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id
# 0    171.76       104.01        103.54        5.21       3.30  111.42  A_1
# 1    171.87       104.17        104.13        6.00       3.31  112.09  A_2
# 2    172.00       104.58        104.29        4.99       3.39  111.57  A_3
# 3    172.49       104.55        104.34        4.44       3.03  113.20  A_4
# 4    171.65       103.63        103.56        3.77       3.16  113.33  A_5

# %%
#Dropping the columns I took out also from the training data.
df_test.drop(columns = ['diagonal', 'height_left','height_right', 'id'], inplace = True)

# %%
df_test
# Out:
#    margin_low  margin_up  length
# 0        5.21       3.30  111.42
# 1        6.00       3.31  112.09
# 2        4.99       3.39  111.57
# 3        4.44       3.03  113.20
# 4        3.77       3.16  113.33

# %%
scaler.fit(df_test)
scaled=scaler.transform(df_test)

# %%
df_test_sc = pd.DataFrame(scaled, columns=df_test.columns)

# %% [markdown]
# ### Train

# %%
# Training the logistic regression model
model = smf.ols(formula='is_genuine ~ margin_low + margin_up + length', data=df_sc_final)
result_final = model.fit()
print(result_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             is_genuine   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     415.1
# Date:                Thu, 09 May 2024   Prob (F-statistic):           6.89e-77
# Time:                        17:00:01   Log-Likelihood:                 61.227
# No. Observations:                 170   AIC:                            -114.5
# Df Residuals:                     166   BIC:                            -101.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5882      0.013     44.901      0.000       0.562       0.614
# ...

# %%
proba = 1 / (1 + np.exp( - result_final.fittedvalues ))

# %%
proba.hist( color= 'salmon')
# Out:
# <Axes: >

# %% [markdown]
# ### Test

# %%
df_test_sc
# Out:
#    margin_low  margin_up    length
# 0    0.438224   0.485681 -1.124014
# 1    1.493702   0.564017 -0.289103
# 2    0.144293   1.190702 -0.937094
# 3   -0.590533  -1.629382  1.094107
# 4   -1.485686  -0.611018  1.256104

# %%
y_pred = result_final.predict(df_test_sc[['margin_low', 'margin_up', 'length']])

# %%
y_pred
# Out:
# 0    0.224105
# 1    0.047734
# 2    0.216855
# 3    1.175493
# 4    1.276989
# dtype: float64

# %% [markdown]
# ### Result

# %%
threshold = 0.5
# transforms the list of booleans into an int with 1 = True, 0 = False
predicted_class = (y_pred > threshold).astype(int)
print(predicted_class)
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# dtype: int32

# %% [markdown]
# Comment: According to this the first three rows are false and last two are true

# %%
df_test ['is_genuine'] = predicted_class

# %%
df_test
# Out:
#    margin_low  margin_up  length  is_genuine
# 0        5.21       3.30  111.42           0
# 1        6.00       3.31  112.09           0
# 2        4.99       3.39  111.57           0
# 3        4.44       3.03  113.20           1
# 4        3.77       3.16  113.33           1
